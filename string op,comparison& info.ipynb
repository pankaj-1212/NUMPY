# %%
import numpy as np

# %%
ch_name="pankaj yadav"
str1="learning python numpy"

# %%
np.char.add(ch_name,str1)    #for merg/add two or more string
# Out:
# array('pankaj yadavlearning python numpy', dtype='<U33')

# %%
np.char.lower(ch_name)  #for print in small letter
# Out:
# array('pankaj yadav', dtype='<U12')

# %%
np.char.upper(str1)   #for print in capital letter
# Out:
# array('LEARNING PYTHON NUMPY', dtype='<U21')

# %%
np.char.center(str1,60)   #for write any string in mid
# Out:
# array('                   learning python numpy                    ',
#       dtype='<U60')

# %%
np.char.center(str1,60,fillchar="*")   #for add any char before and after of center word
# Out:
# array('*******************learning python numpy********************',
#       dtype='<U60')

# %%
np.char.split(ch_name)   #for split b/w str
# Out:
# array(list(['pankaj', 'yadav']), dtype=object)

# %%
np.char.splitlines("hello\nindian") #for splite diff b/w any word
# Out:
# array(list(['hello', 'indian']), dtype=object)

# %%
str4="dmy"    #for add any thing b/w all elem
str5="dmy"

# %%
np.char.join([":","/"],[str4,str5])   #llike it
# Out:
# array(['d:m:y', 'd/m/y'], dtype='<U5')

# %%
np.char.replace(ch_name,"yadav","yadav420")  #use for replace any word by other word
# Out:
# array('pankaj yadav420', dtype='<U15')

# %%
np.char.equal(str4,str5)  #if both string is equal then true otherwise false
# Out:
# array(True)

# %%
np.char.count(ch_name,"a")   #pankaj yadav=total 4 a available
# Out:
# array(4)

# %%
ch_name
# Out:
# 'pankaj yadav'

# %%
np.char.find(ch_name,"y")  #for check any particular latter or word if present then give o/p in form of index no of an array
# Out:
# array(7)
